# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt

# %%
df = web.DataReader('AAPL', 'yahoo', start='2020-03-03', end='2022-09-28')['Close']
df.head(100)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-03-03  76.000000  71.449997  75.917503  72.330002  319475600.0  71.146072
# 2020-03-04  75.849998  73.282501  74.110001  75.684998  219178400.0  74.446152
# 2020-03-05  74.887497  72.852501  73.879997  73.230003  187572800.0  72.031342
# 2020-03-06  72.705002  70.307503  70.500000  72.257500  226176800.0  71.074753
# 2020-03-09  69.522499  65.750000  65.937500  66.542503  286744800.0  65.453308
# ...               ...        ...        ...        ...          ...        ...
# 2020-07-17  97.147499  95.839996  96.987503  96.327499   92186800.0  95.007263
# 2020-07-20  98.500000  96.062500  96.417503  98.357498   90318000.0  97.009438
# 2020-07-21  99.250000  96.742500  99.172501  97.000000  103433200.0  95.670555
# 2020-07-22  97.974998  96.602501  96.692497  97.272499   89001600.0  95.939316
# 2020-07-23  97.077499  92.010002  96.997498  92.845001  197004400.0  91.572487
#
# [100 rows x 6 columns]

# %%
# Bull markets is a market condition where investors are expecting prices to rise.
# Bear markets is a market condition where investors are expecting prices to fall.
# 
# Calculating SMA (simple moving average *apply equal weight to all data points)
#
# Close price is different from adjusted close price because adjusted close price takes into consideration dividends paid.
#
# Closing Price is the last price at which a stock trades during a regular trading session

# %%
# We need to get 100 data points from the date provided.

# %%
# end = dt.datetime.today()
